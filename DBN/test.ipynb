# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import ast

# %%
dataset_path = "/home/jmzzz/Repos/topicosnlp/RBM/data.csv"  

# Cargar el dataset con pandas
df = pd.read_csv(dataset_path)

# Procesar la columna 'piano_roll' convirtiendo el string en un array NumPy
piano_rolls = []
for index, row in df.iterrows():
    piano_roll_str = row["piano_roll"]
    try:
        # Es posible que el string incluya saltos de línea; eliminarlos y evaluar el string
        piano_roll_str = piano_roll_str.replace('\n', ' ').strip()
        piano_roll_array = np.array(ast.literal_eval(piano_roll_str))
    except Exception as e:
        print(f"Error al convertir 'piano_roll' en la fila {index}: {e}")
        continue
    piano_rolls.append(piano_roll_array)

if len(piano_rolls) == 0:
    raise ValueError("No se pudo cargar ningún piano roll desde el dataset.")

# Asumimos que todos los piano rolls tienen la misma forma, por ejemplo, (88, time_steps)
piano_roll_shape = piano_rolls[0].shape
print("Forma de cada piano_roll:", piano_roll_shape)

# Convertir la lista de arrays a un solo array de NumPy y aplanarlo:
data_np = np.stack(piano_rolls, axis=0)       # Forma: (n_samples, 88, time_steps)
n_samples = data_np.shape[0]
data_np_flat = data_np.reshape(n_samples, -1)   # Cada ejemplo es un vector

# Convertir a tensor de PyTorch
data_tensor = torch.tensor(data_np_flat, dtype=torch.float)

# ================================================
# 2. Definir las clases RBM y DBN
# ================================================
class RBM(nn.Module):
    def __init__(self, n_visible, n_hidden):
        super(RBM, self).__init__()
        self.n_visible = n_visible
        self.n_hidden = n_hidden
        # Inicializar pesos y biases
        self.W = nn.Parameter(torch.randn(n_hidden, n_visible) * 0.1)
        self.h_bias = nn.Parameter(torch.zeros(n_hidden))
        self.v_bias = nn.Parameter(torch.zeros(n_visible))
    
    def sample_h(self, v):
        # Calcula la probabilidad de activación de las unidades ocultas
        p_h = torch.sigmoid(torch.matmul(v, self.W.t()) + self.h_bias)
        h_sample = torch.bernoulli(p_h)
        return p_h, h_sample
    
    def sample_v(self, h):
        # Calcula la probabilidad de activación de las unidades visibles
        p_v = torch.sigmoid(torch.matmul(h, self.W) + self.v_bias)
        v_sample = torch.bernoulli(p_v)
        return p_v, v_sample
    
    def forward(self, v):
        # Paso de codificación y reconstrucción
        _, h = self.sample_h(v)
        _, v_reconstructed = self.sample_v(h)
        return v_reconstructed

    def contrastive_divergence(self, v, k=1, lr=0.01):
        v0 = v
        for _ in range(k):
            p_h, h = self.sample_h(v)
            p_v, v = self.sample_v(h)
        # Cálculo de gradientes: diferencia entre la activación de la capa oculta en la muestra original y la reconstruida
        p_h0, _ = self.sample_h(v0)
        p_hk, _ = self.sample_h(v)
        # Actualización manual de parámetros
        self.W.grad = -(torch.matmul(p_h0.t(), v0) - torch.matmul(p_hk.t(), v))
        self.v_bias.grad = -torch.sum(v0 - v, dim=0)
        self.h_bias.grad = -torch.sum(p_h0 - p_hk, dim=0)
        for param in [self.W, self.v_bias, self.h_bias]:
            param.data -= lr * param.grad
        loss = torch.mean(torch.sum((v0 - v) ** 2, dim=1))
        return loss

class DBN:
    def __init__(self, layers, lr=0.01, k=1, device='cpu'):
        """
        layers: lista con los tamaños de cada capa [n_visible, n_hidden1, n_hidden2, ...]
        """
        self.device = device
        self.rbms = []
        self.lr = lr
        self.k = k
        for i in range(len(layers) - 1):
            rbm = RBM(layers[i], layers[i+1]).to(device)
            self.rbms.append(rbm)
    
    def train(self, data, epochs=10, batch_size=64):
        num_samples = data.size(0)
        for idx, rbm in enumerate(self.rbms):
            print(f"Entrenando RBM {idx+1}/{len(self.rbms)}")
            for epoch in range(epochs):
                epoch_loss = 0
                permutation = torch.randperm(num_samples)
                for i in range(0, num_samples, batch_size):
                    batch_idx = permutation[i:i+batch_size]
                    batch = data[batch_idx].to(self.device)
                    loss = rbm.contrastive_divergence(batch, k=self.k, lr=self.lr)
                    epoch_loss += loss.item()
                print(f"  Época {epoch+1}: Loss = {epoch_loss/num_samples:.4f}")
            # Transformar los datos para la siguiente RBM
            _, data = rbm.sample_h(data.to(self.device))
    
    def generate(self, seed, steps=1000):
        # Elevar la semilla a la representación de la última capa
        v = seed.to(self.device)
        for rbm in self.rbms[:-1]:
            _, v = rbm.sample_h(v)
        # En la capa superior, realizar Gibbs sampling
        top_rbm = self.rbms[-1]
        for _ in range(steps):
            _, h = top_rbm.sample_h(v)
            _, v = top_rbm.sample_v(h)
        # Reconstrucción descendente
        for rbm in reversed(self.rbms[:-1]):
            _, v = rbm.sample_v(v)
        return v

    def save(self, path):
        # Guarda el estado de cada RBM
        state = {'rbms': [rbm.state_dict() for rbm in self.rbms]}
        torch.save(state, path)
        print(f"Modelo guardado en {path}")
    
    def load(self, path):
        state = torch.load(path)
        for rbm, rbm_state in zip(self.rbms, state['rbms']):
            rbm.load_state_dict(rbm_state)
        print(f"Modelo cargado desde {path}")

# ================================================
# 3. Configuración y Entrenamiento
# ================================================
# Usar GPU si está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Usando dispositivo:", device)

# Definir la arquitectura de la DBN
input_size = data_tensor.shape[1]  # Tamaño del piano roll aplanado
# Ejemplo: dos capas ocultas con 500 y 200 neuronas
layers = [input_size, 512, 256,128]

# Crear e instanciar la DBN
dbn = DBN(layers, lr=0.01, k=1, device=device)

# Entrenar la DBN
print("Iniciando entrenamiento de la DBN...")
dbn.train(data_tensor, epochs=10, batch_size=16)

# ================================================
# 4. Generación y Guardado del Modelo
# ================================================
# Usar una semilla: por ejemplo, el primer piano roll del dataset
seed = data_tensor[0]
generated = dbn.generate(seed, steps=500)

# Reconstruir la forma original del piano roll
generated_np = generated.cpu().detach().numpy().reshape(piano_roll_shape)
print("Piano roll generado (formato NumPy):")
print(generated_np)

# Guardar el modelo entrenado
dbn.save("modelo_dbn_musica.pth")

# %%
import pandas as pd
import numpy as np
import ast
import torch

# Ruta del CSV
csv_path = "/home/jmzzz/Repos/topicosnlp/RBM/data.csv"

# Cargar el dataset
df = pd.read_csv(csv_path)

# Lista para almacenar los piano rolls convertidos
piano_rolls = []

# Recorrer cada fila del DataFrame y convertir la columna 'piano_roll'
for index, row in df.iterrows():
    piano_roll_str = row["piano_roll"]
    
    # Si encuentras "..." significa que la representación está truncada.
    if "..." in piano_roll_str:
        print(f"Fila {index}: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.")
        continue

    try:
        # Convertir la cadena a un array de Python y luego a un array NumPy
        piano_roll_array = np.array(ast.literal_eval(piano_roll_str))
    except Exception as e:
        print(f"Error al convertir 'piano_roll' en la fila {index}: {e}")
        continue

    piano_rolls.append(piano_roll_array)

# Verificar que se cargó al menos un piano roll completo
if len(piano_rolls) == 0:
    raise ValueError("No se pudo cargar ningún piano roll completo desde el dataset.")

# Asumir que todos los piano rolls tienen la misma forma
piano_roll_shape = piano_rolls[0].shape
print("Forma de cada piano roll:", piano_roll_shape)

# Convertir la lista de arrays a un solo array de NumPy y aplanarlo
data_np = np.stack(piano_rolls, axis=0)       # Forma: (n_samples, height, width)
n_samples = data_np.shape[0]
data_np_flat = data_np.reshape(n_samples, -1)   # Cada ejemplo es un vector

# Convertir a tensor de PyTorch
data_tensor = torch.tensor(data_np_flat, dtype=torch.float)

# Ahora ya tienes 'data_tensor' listo para usar en tu DBN.
print("Dataset cargado correctamente. Tensor shape:", data_tensor.shape)
# Out:
# Fila 0: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 1: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 2: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 3: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 4: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 5: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 6: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 7: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 8: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 9: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 10: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 11: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 12: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 13: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 14: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 15: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 16: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 17: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 18: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 19: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 20: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 21: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 22: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 23: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 24: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 25: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 26: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 27: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 28: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 29: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 30: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 31: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 32: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 33: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 34: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 35: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 36: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 37: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 38: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 39: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 40: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 41: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 42: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 43: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 44: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 45: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 46: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 47: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 48: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 49: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 50: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 51: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 52: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 53: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 54: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 55: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 56: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 57: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 58: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 59: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 60: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 61: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 62: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 63: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 64: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 65: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 66: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 67: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 68: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 69: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 70: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 71: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 72: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 73: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 74: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 75: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 76: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 77: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 78: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 79: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 80: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 81: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 82: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 83: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 84: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 85: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 86: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 87: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 88: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 89: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 90: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 91: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 92: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 93: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 94: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 95: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 96: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 97: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 98: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 99: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 100: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 101: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 102: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 103: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 104: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 105: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 106: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 107: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 108: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 109: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 110: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 111: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 112: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 113: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 114: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 115: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 116: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 117: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 118: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 119: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 120: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 121: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 122: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 123: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 124: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 125: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 126: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 127: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 128: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 129: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 130: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 131: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 132: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 133: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 134: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 135: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 136: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 137: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 138: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 139: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 140: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 141: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 142: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 143: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 144: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 145: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 146: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 147: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 148: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 149: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 150: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 151: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 152: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 153: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 154: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 155: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 156: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 157: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 158: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 159: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 160: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 161: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 162: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 163: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 164: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 165: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 166: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 167: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 168: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 169: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 170: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 171: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 172: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 173: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 174: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 175: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 176: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 177: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 178: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 179: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 180: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 181: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 182: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 183: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 184: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 185: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 186: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 187: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 188: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 189: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 190: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 191: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 192: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 193: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 194: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 195: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 196: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 197: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 198: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 199: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 200: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 201: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 202: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 203: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 204: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 205: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 206: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 207: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 208: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 209: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 210: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 211: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 212: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 213: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 214: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 215: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 216: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 217: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 218: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 219: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 220: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 221: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 222: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 223: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 224: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 225: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 226: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 227: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 228: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 229: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 230: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 231: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 232: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 233: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 234: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 235: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 236: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 237: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 238: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 239: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 240: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 241: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 242: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 243: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 244: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 245: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 246: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 247: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 248: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 249: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 250: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 251: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 252: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 253: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 254: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 255: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 256: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 257: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 258: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 259: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 260: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 261: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 262: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 263: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 264: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 265: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 266: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 267: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 268: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 269: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 270: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 271: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 272: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 273: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 274: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 275: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 276: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 277: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 278: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 279: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 280: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 281: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 282: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 283: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 284: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 285: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 286: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 287: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 288: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 289: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 290: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 291: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 292: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 293: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 294: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 295: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# Fila 296: Se encontró '...' en la representación. Asegúrate de que el piano roll esté guardado completo.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 35
#      33 # Verificar que se cargó al menos un piano roll completo
#      34 if len(piano_rolls) == 0:
# ---> 35     raise ValueError("No se pudo cargar ningún piano roll completo desde el dataset.")
#      37 # Asumir que todos los piano rolls tienen la misma forma
#      38 piano_roll_shape = piano_rolls[0].shape
#
# ValueError: No se pudo cargar ningún piano roll completo desde el dataset.
